# %%
import time
import pandas as pd
import requests
import json5

# %%
df = pd.read_csv("../Data/Employment_Projections.csv").sort_values('Employment 2030',ascending=False)

# %%
df.columns
# Out:
# Index(['Occupation Title', 'Occupation Code', 'Employment 2020',
#        'Employment 2030', 'Employment Change, 2020-2030',
#        'Employment Percent Change, 2020-2030',
#        'Occupational Openings, 2020-2030 Annual Average',
#        'Median Annual Wage 2020', 'Typical Entry-Level Education',
#        'Education Code', 'Work Experience in a Related Occupation',
#        'Workex Code', 'Typical on-the-job Training', 'trCode'],
#       dtype='object')

# %%
df.head(10)
# Out:
#                                     Occupation Title Occupation Code  \
# 0                Home health and personal care aides      ="31-1120"
# 1                      Fast food and counter workers      ="35-3023"
# 2  Retail salespersons    * Automotive Salesperso...      ="41-2031"
# 3  Registered nurses    * CCU Nurse* CNS* Clinica...      ="29-1141"
# 4  Laborers and freight, stock, and material move...      ="53-7062"
# 5  Cashiers    * Cash Register Operator* Check Ou...      ="41-2011"
# 6  Customer service representatives    * Complain...      ="43-4051"
# 7  Office clerks, general    * Administrative Cle...      ="43-9061"
# 8  General and operations managers    * Departmen...      ="11-1021"
# 9  Waiters and waitresses    * Cocktail Server* C...      ="35-3031"
#
#   Employment 2020 Employment 2030 Employment Change, 2020-2030  \
# 0         3,470.7         4,600.6                      1,129.9
# 1         3,455.5         3,973.0                        517.5
# ...

# %%
df.columns
# Out:
# Index(['Occupation Title', 'Occupation Code', 'Employment 2020',
#        'Employment 2030', 'Employment Change, 2020-2030',
#        'Employment Percent Change, 2020-2030',
#        'Occupational Openings, 2020-2030 Annual Average',
#        'Median Annual Wage 2020', 'Typical Entry-Level Education',
#        'Education Code', 'Work Experience in a Related Occupation',
#        'Workex Code', 'Typical on-the-job Training', 'trCode'],
#       dtype='object')

# %%
df[['Occupation Title','Employment 2030','Median Annual Wage 2020','Typical Entry-Level Education','Work Experience in a Related Occupation',
   'Typical on-the-job Training']].head(5)
# Out:
#                                     Occupation Title Employment 2030  \
# 0                Home health and personal care aides         4,600.6
# 1                      Fast food and counter workers         3,973.0
# 2  Retail salespersons    * Automotive Salesperso...         3,795.7
# 3  Registered nurses    * CCU Nurse* CNS* Clinica...         3,356.8
# 4  Laborers and freight, stock, and material move...         3,077.5
#
#   Median Annual Wage 2020      Typical Entry-Level Education  \
# 0                  27,080  High school diploma or equivalent
# 1                  23,860   No formal educational credential
# 2                  27,080   No formal educational credential
# 3                  75,330                  Bachelor's degree
# 4                  31,120   No formal educational credential
#
#   Work Experience in a Related Occupation     Typical on-the-job Training
# 0                                    None  Short-term on-the-job training
# ...
