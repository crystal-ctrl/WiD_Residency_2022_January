# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from IPython import display
# %matplotlib inline
import seaborn as sns

# %%
# read in csv file

df = pd.read_csv('LinkedIn_Job_Postings.csv')
df.head()
# Out:
#          Date                                       Company  \
# 0  2022-02-05                                 Sutter Health
# 1  2022-02-05                                Dignity Health
# 2  2022-01-10                              Half Price Books
# 3  2022-02-05                             Intel Corporation
# 4  2022-02-02  Berkshire Hathaway GUARD Insurance Companies
#
#                                                Title  \
# 0                    Patient Services Representative
# 1                      Medical Office Representative
# 2                                         Bookseller
# 3                                   Planning Analyst
# 4  Underwriting Analyst Trainee - Commercial Line...
#
#                                             Job Link
# 0  https://www.linkedin.com/jobs/view/patient-ser...
# 1  https://www.linkedin.com/jobs/view/medical-off...
# 2  https://www.linkedin.com/jobs/view/bookseller-...
# 3  https://www.linkedin.com/jobs/view/planning-an...
# 4  https://www.linkedin.com/jobs/view/underwritin...

# %%
df.shape
# Out:
# (998, 4)

# %%
df.describe()
# Out:
#               Date         Company  \
# count          998             998
# unique          31             406
# top     2022-02-02  Dignity Health
# freq           117              39
#
#                                              Title  \
# count                                          998
# unique                                         821
# top     FT Customer Support Agent - Work From Home
# freq                                            10
#
#                                                  Job Link
# count                                                 998
# unique                                                998
# top     https://www.linkedin.com/jobs/view/insurance-a...
# freq                                                    1

# %%
df.dtypes
# Out:
# Date        object
# Company     object
# Title       object
# Job Link    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date        0
# Company     0
# Title       0
# Job Link    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      998 non-null    object
#  1   Company   998 non-null    object
#  2   Title     998 non-null    object
#  3   Job Link  998 non-null    object
# dtypes: object(4)
# memory usage: 31.3+ KB

# %% [markdown]
# ## Which companies have the most job postings?

# %%
# Count openings by company
jobs_by_company = df.groupby(['Company'])['Company'].count().sort_values(ascending=False).head(20)
jobs_by_company
# Out:
# Company
# Dignity Health                                                                             39
# ACTIVE RELOCATION (SWITZERLAND) SA                                                         33
# Southcentral Employment Corporation                                                        21
# NHS Redcar and Cleveland                                                                   21
# IABD                                                                                       21
# Intel Corporation                                                                          20
# Phoenix Healthcare LLC                                                                     19
# Centene Corporation                                                                        18
# Greg's List - DC                                                                           16
# Sarah's Inn                                                                                15
# Magellan Health                                                                            15
# California ISO                                                                             15
# Assemblée parlementaire de la Mediterranée/ Parliamentary Assembly of the Mediterranean    13
# Vallis Consulting                                                                          11
# Tea People Ltd.                                                                            11
# Petlab Co.                                                                                 10
# CHRISTOPHER GUY                                                                             9
# Ooms architecten                                                                            8
# Christ Reformed Church                                                                      8
# Picture                                                                                     7
# Name: Company, dtype: int64

# %%
# Plot postings by company

plt.figure(figsize=(12,8))

jobs_by_company.sort_values().plot(kind='barh')
plt.xlabel("Number of Postings", size=15)
plt.ylabel("Company", size=15)
plt.title("Companies with the Most Job Openings", size=18)
# Out:
# Text(0.5, 1.0, 'Companies with the Most Job Openings')

# %% [markdown]
# ## What are the most frequently occuring job titles that are posted?

# %%
# Count number of jobs by title
jobs_by_title = df.groupby(['Title'])['Title'].count().sort_values(ascending=False).head(20)
jobs_by_title
# Out:
# Title
# FT Customer Support Agent - Work From Home         10
# Finance Analyst                                    10
# Executive Assistant                                 9
# Office Support Specialist MediCal                   9
# Patient Registration Representative                 7
# Receptionist                                        7
# HR Administrator                                    6
# Medical Receptionist                                6
# Finance Assistant                                   6
# Business Analyst                                    5
# FT Customer Support Specialist - Work From Home     5
# Legal Secretary                                     5
# EMPLOYEE HEALTH COORD                               5
# Sales Operations Analyst                            5
# Laboratory Assistant - Certified                    4
# Planning Analyst                                    3
# Clinical Research Associate                         3
# Italian Speaking Digital Media Executive            3
# Assistant Accountant                                3
# HR Advisor                                          3
# Name: Title, dtype: int64

# %%
# Plot number of jobs by title

plt.figure(figsize=(12,8))

jobs_by_title.sort_values().plot(kind='barh')
plt.xlabel("Number of Jobs Posted", size=15)
plt.ylabel("Job Titles", size=15)
plt.title("Open Roles by Job Title", size = 18)
# Out:
# Text(0.5, 1.0, 'Open Roles by Job Title')
